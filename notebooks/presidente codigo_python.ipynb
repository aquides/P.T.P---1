# %%
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

# %%
import pandas as pd
base = pd.read_csv('base.csv')

df = base.loc[ (base.SG_UF == 'DF')].reset_index(drop=True)

df = df.drop(['Unnamed: 0', 'DT_GERACAO', 'HH_GERACAO', 'NM_TIPO_ELEICAO', 'CD_ELEICAO', 'DS_ELEICAO', 'DT_ELEICAO', 'TP_ABRANGENCIA', 'SG_UE', 'NM_UE', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_LOCAL_VOTACAO', 'NM_LOCAL_VOTACAO', 'DS_LOCAL_VOTACAO_ENDERECO'], axis=1)

turno1 = df.loc[ df.NR_TURNO == 1].reset_index(drop=True)
turno2 = df.loc[ df.NR_TURNO == 2].reset_index(drop=True)

regional_turno1 = turno1[['NR_ZONA', 'NM_VOTAVEL', 'QT_VOTOS']].groupby(['NR_ZONA', 'NM_VOTAVEL']).sum().sort_values(['NR_ZONA', 'QT_VOTOS'],ascending=False).reset_index()

desempenho_turno1 = turno1[['QT_VOTOS', 'NM_VOTAVEL' ]].groupby(['NM_VOTAVEL']).sum().sort_values('QT_VOTOS',ascending=False).reset_index()

desempenho_turno1['Porcentagem do Total'] = desempenho_turno1.QT_VOTOS / (desempenho_turno1.QT_VOTOS.sum()) * 100
desempenho_turno1['Soma Acumuluda'] = desempenho_turno1.QT_VOTOS.cumsum()
desempenho_turno1['Portentagem Acumuluda'] = desempenho_turno1['Porcentagem do Total'].cumsum()

# %%
pd.set_option('display.max_columns', 500)
base.head()
# Out:
#    Unnamed: 0  DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 0           0  01/11/2022   16:05:25         2022                2
# 1           1  01/11/2022   16:05:25         2022                2
# 2           2  01/11/2022   16:05:25         2022                2
# 3           3  01/11/2022   16:05:25         2022                2
# 4           4  01/11/2022   16:05:25         2022                2
#
#      NM_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO                  DS_ELEICAO  \
# 0  ELEIÇÃO ORDINÁRIA         1         544  ELEIÇÃO GERAL FEDERAL 2022
# 1  ELEIÇÃO ORDINÁRIA         1         544  ELEIÇÃO GERAL FEDERAL 2022
# 2  ELEIÇÃO ORDINÁRIA         1         544  ELEIÇÃO GERAL FEDERAL 2022
# 3  ELEIÇÃO ORDINÁRIA         1         544  ELEIÇÃO GERAL FEDERAL 2022
# 4  ELEIÇÃO ORDINÁRIA         1         544  ELEIÇÃO GERAL FEDERAL 2022
#
#    DT_ELEICAO TP_ABRANGENCIA SG_UF SG_UE   NM_UE  CD_MUNICIPIO  \
# 0  02/10/2022              F    MS    BR  BRASIL         98116
# ...

# %%
base.shape
# Out:
# (5380736, 27)

# %%
df = base.loc[ (base.SG_UF == 'DF')].reset_index(drop=True)

df = df.drop(['Unnamed: 0', 'DT_GERACAO', 'HH_GERACAO', 'NM_TIPO_ELEICAO', 'CD_ELEICAO', 'DS_ELEICAO', 'DT_ELEICAO', 'TP_ABRANGENCIA', 'SG_UE', 'NM_UE', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_LOCAL_VOTACAO', 'NM_LOCAL_VOTACAO', 'DS_LOCAL_VOTACAO_ENDERECO'], axis=1)


turno1 = df.loc[ df.NR_TURNO == 1].reset_index(drop=True)
turno2 = df.loc[ df.NR_TURNO == 2].reset_index(drop=True)

regional_turno1 = turno1[['NR_ZONA', 'NM_VOTAVEL', 'QT_VOTOS']].groupby(['NR_ZONA', 'NM_VOTAVEL']).sum().sort_values(['NR_ZONA', 'QT_VOTOS'],ascending=False).reset_index()

desempenho_turno1 = turno1[['QT_VOTOS', 'NM_VOTAVEL' ]].groupby(['NM_VOTAVEL']).sum().sort_values('QT_VOTOS',ascending=False).reset_index()

desempenho_turno1['Porcentagem do Total'] = desempenho_turno1.QT_VOTOS / (desempenho_turno1.QT_VOTOS.sum()) * 100
desempenho_turno1['Soma Acumuluda'] = desempenho_turno1.QT_VOTOS.cumsum()
desempenho_turno1['Portentagem Acumuluda'] = desempenho_turno1['Porcentagem do Total'].cumsum()

# %%
# df = df.drop(['Unnamed: 0', 'DT_GERACAO', 'HH_GERACAO', 'NM_TIPO_ELEICAO', 'CD_ELEICAO', 'DS_ELEICAO', 'DT_ELEICAO', 'TP_ABRANGENCIA', 'SG_UE', 'NM_UE', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_LOCAL_VOTACAO', 'NM_LOCAL_VOTACAO', 'DS_LOCAL_VOTACAO_ENDERECO'], axis=1)

# turno1 = df.loc[ df.NR_TURNO == 1].reset_index(drop=True)
# turno2 = df.loc[ df.NR_TURNO == 2].reset_index(drop=True)

# regional_turno1 = turno1[['NR_ZONA', 'NM_VOTAVEL', 'QT_VOTOS']].groupby(['NR_ZONA', 'NM_VOTAVEL']).sum().sort_values(['NR_ZONA', 'QT_VOTOS'],ascending=False).reset_index()

# desempenho_turno1 = turno1[['QT_VOTOS', 'NM_V
# OTAVEL' ]].groupby(['NM_VOTAVEL']).sum().sort_values('QT_VOTOS',ascending=False).reset_index()

# desempenho_turno1['Porcentagem do Total'] = desempenho_turno1.QT_VOTOS / (desempenho_turno1.QT_VOTOS.sum()) * 100
# desempenho_turno1['Soma Acumuluda'] = desempenho_turno1.QT_VOTOS.cumsum()
# desempenho_turno1['Portentagem Acumuluda'] = desempenho_turno1['Porcentagem do Total'].cumsum()

# %%
turno1 = df.loc[ df.NR_TURNO == 1].reset_index(drop=True)
turno2 = df.loc[ df.NR_TURNO == 2].reset_index(drop=True)

regional_turno1 = turno1[['NR_ZONA', 'NM_VOTAVEL', 'QT_VOTOS']].groupby(['NR_ZONA', 'NM_VOTAVEL']).sum().sort_values(['NR_ZONA', 'QT_VOTOS'],ascending=False).reset_index()

desempenho_turno1 = turno1[['QT_VOTOS', 'NM_VOTAVEL' ]].groupby(['NM_VOTAVEL']).sum().sort_values('QT_VOTOS',ascending=False).reset_index()

desempenho_turno1['Porcentagem do Total'] = desempenho_turno1.QT_VOTOS / (desempenho_turno1.QT_VOTOS.sum()) * 100
desempenho_turno1['Soma Acumuluda'] = desempenho_turno1.QT_VOTOS.cumsum()
desempenho_turno1['Portentagem Acumuluda'] = desempenho_turno1['Porcentagem do Total'].cumsum()

# %%
turno1.NM_VOTAVEL.unique()
# Out:
# array(['LUIZ INÁCIO LULA DA SILVA', 'JOSE MARIA EYMAEL',
#        'KELMON LUIS DA SILVA SOUZA', 'LUIZ FELIPE CHAVES D AVILA',
#        'VOTO BRANCO', 'SORAYA VIEIRA THRONICKE', 'CIRO FERREIRA GOMES',
#        'SOFIA PADUA MANZANO', 'JAIR MESSIAS BOLSONARO',
#        'SIMONE NASSAR TEBET', 'LEONARDO PÉRICLES VIEIRA ROQUE',
#        'VOTO NULO', 'VERA LUCIA PEREIRA DA SILVA SALGADO'], dtype=object)

# %%
turno1[['NR_ZONA', 'QT_VOTOS']].groupby(['NR_ZONA']).sum()
# Out:
#          QT_VOTOS
# NR_ZONA
# 1           63150
# 2           91541
# 3           59717
# 4           82978
# 5          107202
# 6          110662
# 8          111346
# 9          109334
# 10          99635
# 11          63492
# 13         113818
# 14          89446
# 15         135474
# 16         123550
# 17         105216
# 18         105153
# 19          89336
# 20          65491
# 21          93359

# %%
regional_turno1 = turno1[['NR_ZONA', 'NM_VOTAVEL', 'QT_VOTOS']].groupby(['NR_ZONA', 'NM_VOTAVEL']).sum().sort_values(['NR_ZONA', 'QT_VOTOS'],ascending=False).reset_index()

desempenho_turno1 = turno1[['QT_VOTOS', 'NM_VOTAVEL' ]].groupby(['NM_VOTAVEL']).sum().sort_values('QT_VOTOS',ascending=False).reset_index()

desempenho_turno1['Porcentagem do Total'] = desempenho_turno1.QT_VOTOS / (desempenho_turno1.QT_VOTOS.sum()) * 100
desempenho_turno1['Soma Acumuluda'] = desempenho_turno1.QT_VOTOS.cumsum()
desempenho_turno1['Portentagem Acumuluda'] = desempenho_turno1['Porcentagem do Total'].cumsum()

# %%
regional_turno1.to_csv('turno1.csv')

# %%
display(regional_turno1.loc[ (regional_turno1.NM_VOTAVEL == 'JAIR MESSIAS BOLSONARO') | (regional_turno1.NM_VOTAVEL == 'LUIZ INÁCIO LULA DA SILVA') | ( regional_turno1.NM_VOTAVEL ==  'SIMONE NASSAR TEBET')].reset_index(drop=True))
# Out:
#     NR_ZONA                 NM_VOTAVEL  QT_VOTOS
# 0        21     JAIR MESSIAS BOLSONARO     48310
# 1        21  LUIZ INÁCIO LULA DA SILVA     31408
# 2        21        SIMONE NASSAR TEBET      5209
# 3        20     JAIR MESSIAS BOLSONARO     33496
# 4        20  LUIZ INÁCIO LULA DA SILVA     22679
# 5        20        SIMONE NASSAR TEBET      3379
# 6        19     JAIR MESSIAS BOLSONARO     48838
# 7        19  LUIZ INÁCIO LULA DA SILVA     28649
# 8        19        SIMONE NASSAR TEBET      4753
# 9        18     JAIR MESSIAS BOLSONARO     49688
# 10       18  LUIZ INÁCIO LULA DA SILVA     40231
# 11       18        SIMONE NASSAR TEBET      6622
# 12       17     JAIR MESSIAS BOLSONARO     52849
# 13       17  LUIZ INÁCIO LULA DA SILVA     38403
# 14       17        SIMONE NASSAR TEBET      5224
# 15       16     JAIR MESSIAS BOLSONARO     63969
# 16       16  LUIZ INÁCIO LULA DA SILVA     42147
# 17       16        SIMONE NASSAR TEBET      6529
# ...

# %%
turno1.head(1)
# Out:
#    ANO_ELEICAO  CD_TIPO_ELEICAO  NR_TURNO SG_UF  NR_ZONA  NR_SECAO  CD_CARGO  \
# 0         2022                2         1    DF        8       689         1
#
#      DS_CARGO  NR_VOTAVEL                 NM_VOTAVEL  QT_VOTOS  SQ_CANDIDATO
# 0  PRESIDENTE          13  LUIZ INÁCIO LULA DA SILVA       108  280001607829

# %%
desempenho_turno1 = turno1[['QT_VOTOS', 'NM_VOTAVEL' ]].groupby(['NM_VOTAVEL']).sum().sort_values('QT_VOTOS',ascending=False).reset_index()

desempenho_turno1['Porcentagem do Total'] = desempenho_turno1.QT_VOTOS / (desempenho_turno1.QT_VOTOS.sum()) * 100
desempenho_turno1['Soma Acumuluda'] = desempenho_turno1.QT_VOTOS.cumsum()
desempenho_turno1['Portentagem Acumuluda'] = desempenho_turno1['Porcentagem do Total'].cumsum()

# %%
desempenho_turno1.head()
# Out:
#                   NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  Soma Acumuluda  \
# 0     JAIR MESSIAS BOLSONARO    910397             50.024562          910397
# 1  LUIZ INÁCIO LULA DA SILVA    649534             35.690642         1559931
# 2        SIMONE NASSAR TEBET    105377              5.790263         1665308
# 3        CIRO FERREIRA GOMES     74308              4.083081         1739616
# 4                  VOTO NULO     32163              1.767295         1771779
#
#    Portentagem Acumuluda
# 0              50.024562
# 1              85.715204
# 2              91.505467
# 3              95.588549
# 4              97.355844

# %%
aux = desempenho_turno1.head()

sns.barplot(x='NM_VOTAVEL', y='QT_VOTOS', data=aux)

plt.xticks(rotation=80)
plt.show()

# %%
desempenho_turno1['Porcentagem do Total'] = desempenho_turno1.QT_VOTOS / (desempenho_turno1.QT_VOTOS.sum()) * 100
desempenho_turno1['Soma Acumuluda'] = desempenho_turno1.QT_VOTOS.cumsum()
desempenho_turno1['Portentagem Acumuluda'] = desempenho_turno1['Porcentagem do Total'].cumsum()

# %%
desempenho_turno1.head(30)
# Out:
#                              NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  \
# 0                JAIR MESSIAS BOLSONARO    910397             50.024562
# 1             LUIZ INÁCIO LULA DA SILVA    649534             35.690642
# 2                   SIMONE NASSAR TEBET    105377              5.790263
# 3                   CIRO FERREIRA GOMES     74308              4.083081
# 4                             VOTO NULO     32163              1.767295
# 5                           VOTO BRANCO     25162              1.382603
# 6            LUIZ FELIPE CHAVES D AVILA     10342              0.568273
# 7               SORAYA VIEIRA THRONICKE      7935              0.436013
# 8            KELMON LUIS DA SILVA SOUZA      1554              0.085389
# 9        LEONARDO PÉRICLES VIEIRA ROQUE      1262              0.069344
# 10                  SOFIA PADUA MANZANO       894              0.049124
# 11                    JOSE MARIA EYMAEL       518              0.028463
# ...

# %%
desempenho_turno1['Porcentagem do Total'] = desempenho_turno1.QT_VOTOS / (desempenho_turno1.QT_VOTOS.sum()) * 100
desempenho_turno1['Soma Acumuluda'] = desempenho_turno1.QT_VOTOS.cumsum()
desempenho_turno1['Portentagem Acumuluda'] = desempenho_turno1['Porcentagem do Total'].cumsum()

# %%
desempenho_turno2 = turno2[['QT_VOTOS', 'NM_VOTAVEL' ]].groupby(['NM_VOTAVEL']).sum().sort_values('QT_VOTOS',ascending=False).reset_index()

# %%
desempenho_turno2['Porcentagem do Total'] = desempenho_turno2.QT_VOTOS / (desempenho_turno2.QT_VOTOS.sum()) * 100
desempenho_turno2['Soma Acumuluda'] = desempenho_turno2.QT_VOTOS.cumsum()
desempenho_turno2['Portentagem Acumuluda'] = desempenho_turno2['Porcentagem do Total'].cumsum()
desempenho_turno2.head(30)
# Out:
#                   NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  Soma Acumuluda  \
# 0     JAIR MESSIAS BOLSONARO   1041331             56.640497         1041331
# 1  LUIZ INÁCIO LULA DA SILVA    729295             39.668108         1770626
# 2                  VOTO NULO     38203              2.077953         1808829
# 3                VOTO BRANCO     29663              1.613442         1838492
#
#    Portentagem Acumuluda
# 0              56.640497
# 1              96.308605
# 2              98.386558
# 3             100.000000

# %%
aux = desempenho_turno2.head()

sns.barplot(x='NM_VOTAVEL', y='QT_VOTOS', data=desempenho_turno2)

plt.xticks(rotation=80)
plt.show()

# %%
regional_turno2 = turno2[['NR_ZONA', 'NM_VOTAVEL', 'QT_VOTOS']].groupby(['NR_ZONA', 'NM_VOTAVEL']).sum().sort_values(['NR_ZONA', 'QT_VOTOS'],ascending=False).reset_index()

# %%
turno1_zona1 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 1].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona1['Porcentagem do Total'] = turno1_zona1.QT_VOTOS / (turno1_zona1.QT_VOTOS.sum()) * 100
turno1_zona1['Soma Acumuluda'] = turno1_zona1.QT_VOTOS.cumsum()
turno1_zona1['Portentagem Acumuluda'] = turno1_zona1['Porcentagem do Total'].cumsum()
display(turno1_zona1.head(13))

turno1_zona2 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 2].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona2['Porcentagem do Total'] = turno1_zona2.QT_VOTOS / (turno1_zona2.QT_VOTOS.sum()) * 100
turno1_zona2['Soma Acumuluda'] = turno1_zona2.QT_VOTOS.cumsum()
turno1_zona2['Portentagem Acumuluda'] = turno1_zona2['Porcentagem do Total'].cumsum()
display(turno1_zona2.head(13)
        )
turno1_zona3 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 3].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona3['Porcentagem do Total'] = turno1_zona3.QT_VOTOS / (turno1_zona3.QT_VOTOS.sum()) * 100
turno1_zona3['Soma Acumuluda'] = turno1_zona3.QT_VOTOS.cumsum()
turno1_zona3['Portentagem Acumuluda'] = turno1_zona3['Porcentagem do Total'].cumsum()
display(turno1_zona3.head(13))

turno1_zona4 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 4].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona4['Porcentagem do Total'] = turno1_zona4.QT_VOTOS / (turno1_zona4.QT_VOTOS.sum()) * 100
turno1_zona4['Soma Acumuluda'] = turno1_zona4.QT_VOTOS.cumsum()
turno1_zona4['Portentagem Acumuluda'] = turno1_zona4['Porcentagem do Total'].cumsum()
display(turno1_zona4.head(13))

turno1_zona5 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 5].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona5['Porcentagem do Total'] = turno1_zona5.QT_VOTOS / (turno1_zona5.QT_VOTOS.sum()) * 100
turno1_zona5['Soma Acumuluda'] = turno1_zona5.QT_VOTOS.cumsum()
turno1_zona5['Portentagem Acumuluda'] = turno1_zona5['Porcentagem do Total'].cumsum()
display(turno1_zona5.head(13))

turno1_zona6 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 6].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona6['Porcentagem do Total'] = turno1_zona6.QT_VOTOS / (turno1_zona6.QT_VOTOS.sum()) * 100
turno1_zona6['Soma Acumuluda'] = turno1_zona6.QT_VOTOS.cumsum()
turno1_zona6['Portentagem Acumuluda'] = turno1_zona6['Porcentagem do Total'].cumsum()
display(turno1_zona6.head(13))

turno1_zona8 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 8].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona8['Porcentagem do Total'] = turno1_zona8.QT_VOTOS / (turno1_zona8.QT_VOTOS.sum()) * 100
turno1_zona8['Soma Acumuluda'] = turno1_zona8.QT_VOTOS.cumsum()
turno1_zona8['Portentagem Acumuluda'] = turno1_zona8['Porcentagem do Total'].cumsum()
display(turno1_zona8.head(13))

turno1_zona9 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 9].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona9['Porcentagem do Total'] = turno1_zona9.QT_VOTOS / (turno1_zona9.QT_VOTOS.sum()) * 100
turno1_zona9['Soma Acumuluda'] = turno1_zona9.QT_VOTOS.cumsum()
turno1_zona9['Portentagem Acumuluda'] = turno1_zona9['Porcentagem do Total'].cumsum()
display(turno1_zona9.head(13))

turno1_zona10 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 10].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona10['Porcentagem do Total'] = turno1_zona10.QT_VOTOS / (turno1_zona10.QT_VOTOS.sum()) * 100
turno1_zona10['Soma Acumuluda'] = turno1_zona10.QT_VOTOS.cumsum()
turno1_zona10['Portentagem Acumuluda'] = turno1_zona10['Porcentagem do Total'].cumsum()
display(turno1_zona10.head(13))

turno1_zona11 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 11].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona11['Porcentagem do Total'] = turno1_zona11.QT_VOTOS / (turno1_zona11.QT_VOTOS.sum()) * 100
turno1_zona11['Soma Acumuluda'] = turno1_zona11.QT_VOTOS.cumsum()
turno1_zona11['Portentagem Acumuluda'] = turno1_zona11['Porcentagem do Total'].cumsum()
display(turno1_zona11.head(13))

# turno1_zona12 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 1].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

# turno1_zona12['Porcentagem do Total'] = turno1_zona12.QT_VOTOS / (turno1_zona12.QT_VOTOS.sum()) * 100
# turno1_zona12['Soma Acumuluda'] = turno1_zona12.QT_VOTOS.cumsum()
# turno1_zona12['Portentagem Acumuluda'] = turno1_zona12['Porcentagem do Total'].cumsum()
# display(turno1_zona12.head(13))

turno1_zona13 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 13].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona13['Porcentagem do Total'] = turno1_zona13.QT_VOTOS / (turno1_zona13.QT_VOTOS.sum()) * 100
turno1_zona13['Soma Acumuluda'] = turno1_zona13.QT_VOTOS.cumsum()
turno1_zona13['Portentagem Acumuluda'] = turno1_zona13['Porcentagem do Total'].cumsum()
display(turno1_zona13.head(13))

turno1_zona14 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 14].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona14['Porcentagem do Total'] = turno1_zona14.QT_VOTOS / (turno1_zona14.QT_VOTOS.sum()) * 100
turno1_zona14['Soma Acumuluda'] = turno1_zona14.QT_VOTOS.cumsum()
turno1_zona14['Portentagem Acumuluda'] = turno1_zona14['Porcentagem do Total'].cumsum()
display(turno1_zona14.head(13))

turno1_zona15 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 15].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona15['Porcentagem do Total'] = turno1_zona15.QT_VOTOS / (turno1_zona15.QT_VOTOS.sum()) * 100
turno1_zona15['Soma Acumuluda'] = turno1_zona15.QT_VOTOS.cumsum()
turno1_zona15['Portentagem Acumuluda'] = turno1_zona15['Porcentagem do Total'].cumsum()
display(turno1_zona15.head(13))

turno1_zona16 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 16].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona16['Porcentagem do Total'] = turno1_zona16.QT_VOTOS / (turno1_zona16.QT_VOTOS.sum()) * 100
turno1_zona16['Soma Acumuluda'] = turno1_zona16.QT_VOTOS.cumsum()
turno1_zona16['Portentagem Acumuluda'] = turno1_zona16['Porcentagem do Total'].cumsum()
display(turno1_zona16.head(13))

turno1_zona17 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 17].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona17['Porcentagem do Total'] = turno1_zona17.QT_VOTOS / (turno1_zona17.QT_VOTOS.sum()) * 100
turno1_zona17['Soma Acumuluda'] = turno1_zona17.QT_VOTOS.cumsum()
turno1_zona17['Portentagem Acumuluda'] = turno1_zona17['Porcentagem do Total'].cumsum()
display(turno1_zona17.head(13))

turno1_zona18 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 18].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona18['Porcentagem do Total'] = turno1_zona18.QT_VOTOS / (turno1_zona18.QT_VOTOS.sum()) * 100
turno1_zona18['Soma Acumuluda'] = turno1_zona18.QT_VOTOS.cumsum()
turno1_zona18['Portentagem Acumuluda'] = turno1_zona18['Porcentagem do Total'].cumsum()
display(turno1_zona18.head(13))

turno1_zona19 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 19].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona19['Porcentagem do Total'] = turno1_zona19.QT_VOTOS / (turno1_zona19.QT_VOTOS.sum()) * 100
turno1_zona19['Soma Acumuluda'] = turno1_zona19.QT_VOTOS.cumsum()
turno1_zona19['Portentagem Acumuluda'] = turno1_zona19['Porcentagem do Total'].cumsum()
display(turno1_zona19.head(13))

turno1_zona20 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 20].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona20['Porcentagem do Total'] = turno1_zona20.QT_VOTOS / (turno1_zona20.QT_VOTOS.sum()) * 100
turno1_zona20['Soma Acumuluda'] = turno1_zona20.QT_VOTOS.cumsum()
turno1_zona20['Portentagem Acumuluda'] = turno1_zona20['Porcentagem do Total'].cumsum()
display(turno1_zona20.head(13))

turno1_zona21 = turno1[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno1.NR_ZONA == 21].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()

turno1_zona21['Porcentagem do Total'] = turno1_zona21.QT_VOTOS / (turno1_zona21.QT_VOTOS.sum()) * 100
turno1_zona21['Soma Acumuluda'] = turno1_zona21.QT_VOTOS.cumsum()
turno1_zona21['Portentagem Acumuluda'] = turno1_zona21['Porcentagem do Total'].cumsum()
display(turno1_zona21.head(13))
# Out:
#                              NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  \
# 0                JAIR MESSIAS BOLSONARO     28290             44.798100
# 1             LUIZ INÁCIO LULA DA SILVA     24807             39.282660
# 2                   SIMONE NASSAR TEBET      4926              7.800475
# 3                   CIRO FERREIRA GOMES      2734              4.329375
# 4                             VOTO NULO       793              1.255740
# 5            LUIZ FELIPE CHAVES D AVILA       679              1.075218
# 6                           VOTO BRANCO       574              0.908947
# 7               SORAYA VIEIRA THRONICKE       141              0.223278
# 8            KELMON LUIS DA SILVA SOUZA        68              0.107680
# 9                   SOFIA PADUA MANZANO        44              0.069675
# 10       LEONARDO PÉRICLES VIEIRA ROQUE        41              0.064925
# 11                    JOSE MARIA EYMAEL        30              0.047506
# ...

# %%
turno1_zona14.head(13)
# Out:
#                              NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  \
# 0             LUIZ INÁCIO LULA DA SILVA     38685             43.249558
# 1                JAIR MESSIAS BOLSONARO     37288             41.687722
# 2                   SIMONE NASSAR TEBET      6331              7.078014
# 3                   CIRO FERREIRA GOMES      3913              4.374707
# 4                             VOTO NULO      1027              1.148179
# 5            LUIZ FELIPE CHAVES D AVILA       926              1.035261
# 6                           VOTO BRANCO       782              0.874271
# 7               SORAYA VIEIRA THRONICKE       213              0.238133
# 8                   SOFIA PADUA MANZANO        85              0.095029
# 9        LEONARDO PÉRICLES VIEIRA ROQUE        65              0.072670
# 10           KELMON LUIS DA SILVA SOUZA        61              0.068198
# 11                    JOSE MARIA EYMAEL        42              0.046956
# ...

# %%
aux = turno1_zona14.head()

sns.barplot(x='NM_VOTAVEL', y='QT_VOTOS', data=aux)

plt.xticks(rotation=80)
plt.show()

# %%
turno1_zona8 # ceilandia
# Out:
#                              NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  \
# 0                JAIR MESSIAS BOLSONARO     56290             50.554129
# 1             LUIZ INÁCIO LULA DA SILVA     39668             35.625887
# 2                   SIMONE NASSAR TEBET      5707              5.125465
# 3                   CIRO FERREIRA GOMES      4399              3.950748
# 4                             VOTO NULO      2295              2.061143
# 5                           VOTO BRANCO      1771              1.590538
# 6               SORAYA VIEIRA THRONICKE       554              0.497548
# 7            LUIZ FELIPE CHAVES D AVILA       394              0.353852
# 8            KELMON LUIS DA SILVA SOUZA        95              0.085320
# 9        LEONARDO PÉRICLES VIEIRA ROQUE        81              0.072746
# 10                  SOFIA PADUA MANZANO        38              0.034128
# 11                    JOSE MARIA EYMAEL        28              0.025147
# ...

# %%
print('Ceilandia Norte') # ceilandia norte 
turno1_zona16

print('Samambaia')
turno1_zona13 # ceilandia
# Out:
# Ceilandia Norte
# Samambaia
#                              NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  \
# 0                JAIR MESSIAS BOLSONARO     61493             54.027482
# 1             LUIZ INÁCIO LULA DA SILVA     36024             31.650530
# 2                   SIMONE NASSAR TEBET      6151              5.404242
# 3                   CIRO FERREIRA GOMES      4597              4.038904
# 4                             VOTO NULO      2343              2.058550
# 5                           VOTO BRANCO      1828              1.606073
# 6               SORAYA VIEIRA THRONICKE       649              0.570209
# 7            LUIZ FELIPE CHAVES D AVILA       477              0.419090
# 8            KELMON LUIS DA SILVA SOUZA       104              0.091374
# 9        LEONARDO PÉRICLES VIEIRA ROQUE        72              0.063259
# 10                  SOFIA PADUA MANZANO        41              0.036022
# 11  VERA LUCIA PEREIRA DA SILVA SALGADO        22              0.019329
# ...

# %%
print('Samambaia')
turno1_zona13 # ceilandia
# Out:
# Samambaia
#                              NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  \
# 0                JAIR MESSIAS BOLSONARO     61493             54.027482
# 1             LUIZ INÁCIO LULA DA SILVA     36024             31.650530
# 2                   SIMONE NASSAR TEBET      6151              5.404242
# 3                   CIRO FERREIRA GOMES      4597              4.038904
# 4                             VOTO NULO      2343              2.058550
# 5                           VOTO BRANCO      1828              1.606073
# 6               SORAYA VIEIRA THRONICKE       649              0.570209
# 7            LUIZ FELIPE CHAVES D AVILA       477              0.419090
# 8            KELMON LUIS DA SILVA SOUZA       104              0.091374
# 9        LEONARDO PÉRICLES VIEIRA ROQUE        72              0.063259
# 10                  SOFIA PADUA MANZANO        41              0.036022
# 11  VERA LUCIA PEREIRA DA SILVA SALGADO        22              0.019329
# ...

# %%
turno1_zona14
# Out:
#                              NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  \
# 0             LUIZ INÁCIO LULA DA SILVA     38685             43.249558
# 1                JAIR MESSIAS BOLSONARO     37288             41.687722
# 2                   SIMONE NASSAR TEBET      6331              7.078014
# 3                   CIRO FERREIRA GOMES      3913              4.374707
# 4                             VOTO NULO      1027              1.148179
# 5            LUIZ FELIPE CHAVES D AVILA       926              1.035261
# 6                           VOTO BRANCO       782              0.874271
# 7               SORAYA VIEIRA THRONICKE       213              0.238133
# 8                   SOFIA PADUA MANZANO        85              0.095029
# 9        LEONARDO PÉRICLES VIEIRA ROQUE        65              0.072670
# 10           KELMON LUIS DA SILVA SOUZA        61              0.068198
# 11                    JOSE MARIA EYMAEL        42              0.046956
# ...

# %%
print('Ceilandia Norte') # ceilandia norte 
turno1_zona16

print('Samambaia')
turno1_zona13 # ceilandia 

truno2_estatistica = turno2[['NM_VOTAVEL', 'QT_VOTOS']].groupby('NM_VOTAVEL').sum().reset_index()

truno2_estatistica['Porcentagem Acumulada'] = truno2_estatistica.QT_VOTOS / truno2_estatistica.QT_VOTOS.sum() * 100 
truno2_estatistica['Votos Acumulado'] = truno2_estatistica.QT_VOTOS.cumsum()
truno2_estatistica
# Out:
# Ceilandia Norte
# Samambaia
#                   NM_VOTAVEL  QT_VOTOS  Porcentagem Acumulada  Votos Acumulado
# 0     JAIR MESSIAS BOLSONARO   1041331              56.640497          1041331
# 1  LUIZ INÁCIO LULA DA SILVA    729295              39.668108          1770626
# 2                VOTO BRANCO     29663               1.613442          1800289
# 3                  VOTO NULO     38203               2.077953          1838492

# %%
turno2_zona1 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 1].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona1['Porcentagem do Total'] = turno2_zona1.QT_VOTOS / (turno2_zona1.QT_VOTOS.sum()) * 100
turno2_zona1['Soma Acumuluda'] = turno2_zona1.QT_VOTOS.cumsum()
turno2_zona1['Portentagem Acumuluda'] = turno2_zona1['Porcentagem do Total'].cumsum()
display(turno2_zona1.head(13))
 
turno2_zona2 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 2].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona2['Porcentagem do Total'] = turno2_zona2.QT_VOTOS / (turno2_zona2.QT_VOTOS.sum()) * 100
turno2_zona2['Soma Acumuluda'] = turno2_zona2.QT_VOTOS.cumsum()
turno2_zona2['Portentagem Acumuluda'] = turno2_zona2['Porcentagem do Total'].cumsum()
display(turno2_zona2.head(13)
        )
turno2_zona3 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 3].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona3['Porcentagem do Total'] = turno2_zona3.QT_VOTOS / (turno2_zona3.QT_VOTOS.sum()) * 100
turno2_zona3['Soma Acumuluda'] = turno2_zona3.QT_VOTOS.cumsum()
turno2_zona3['Portentagem Acumuluda'] = turno2_zona3['Porcentagem do Total'].cumsum()
display(turno2_zona3.head(13))
 
turno2_zona4 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 4].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona4['Porcentagem do Total'] = turno2_zona4.QT_VOTOS / (turno2_zona4.QT_VOTOS.sum()) * 100
turno2_zona4['Soma Acumuluda'] = turno2_zona4.QT_VOTOS.cumsum()
turno2_zona4['Portentagem Acumuluda'] = turno2_zona4['Porcentagem do Total'].cumsum()
display(turno2_zona4.head(13))
 
turno2_zona5 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 5].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona5['Porcentagem do Total'] = turno2_zona5.QT_VOTOS / (turno2_zona5.QT_VOTOS.sum()) * 100
turno2_zona5['Soma Acumuluda'] = turno2_zona5.QT_VOTOS.cumsum()
turno2_zona5['Portentagem Acumuluda'] = turno2_zona5['Porcentagem do Total'].cumsum()
display(turno2_zona5.head(13))
 
turno2_zona6 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 6].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona6['Porcentagem do Total'] = turno2_zona6.QT_VOTOS / (turno2_zona6.QT_VOTOS.sum()) * 100
turno2_zona6['Soma Acumuluda'] = turno2_zona6.QT_VOTOS.cumsum()
turno2_zona6['Portentagem Acumuluda'] = turno2_zona6['Porcentagem do Total'].cumsum()
display(turno2_zona6.head(13))
 
turno2_zona8 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 8].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona8['Porcentagem do Total'] = turno2_zona8.QT_VOTOS / (turno2_zona8.QT_VOTOS.sum()) * 100
turno2_zona8['Soma Acumuluda'] = turno2_zona8.QT_VOTOS.cumsum()
turno2_zona8['Portentagem Acumuluda'] = turno2_zona8['Porcentagem do Total'].cumsum()
display(turno2_zona8.head(13))
 
turno2_zona9 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 9].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona9['Porcentagem do Total'] = turno2_zona9.QT_VOTOS / (turno2_zona9.QT_VOTOS.sum()) * 100
turno2_zona9['Soma Acumuluda'] = turno2_zona9.QT_VOTOS.cumsum()
turno2_zona9['Portentagem Acumuluda'] = turno2_zona9['Porcentagem do Total'].cumsum()
display(turno2_zona9.head(13))
 
turno2_zona10 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 10].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona10['Porcentagem do Total'] = turno2_zona10.QT_VOTOS / (turno2_zona10.QT_VOTOS.sum()) * 100
turno2_zona10['Soma Acumuluda'] = turno2_zona10.QT_VOTOS.cumsum()
turno2_zona10['Portentagem Acumuluda'] = turno2_zona10['Porcentagem do Total'].cumsum()
display(turno2_zona10.head(13))
 
turno2_zona11 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 11].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona11['Porcentagem do Total'] = turno2_zona11.QT_VOTOS / (turno2_zona11.QT_VOTOS.sum()) * 100
turno2_zona11['Soma Acumuluda'] = turno2_zona11.QT_VOTOS.cumsum()
turno2_zona11['Portentagem Acumuluda'] = turno2_zona11['Porcentagem do Total'].cumsum()
display(turno2_zona11.head(13))
 
# turno2_zona12 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 1].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
# turno2_zona12['Porcentagem do Total'] = turno2_zona12.QT_VOTOS / (turno2_zona12.QT_VOTOS.sum()) * 100
# turno2_zona12['Soma Acumuluda'] = turno2_zona12.QT_VOTOS.cumsum()
# turno2_zona12['Portentagem Acumuluda'] = turno2_zona12['Porcentagem do Total'].cumsum()
# display(turno2_zona12.head(13))
 
turno2_zona13 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 13].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona13['Porcentagem do Total'] = turno2_zona13.QT_VOTOS / (turno2_zona13.QT_VOTOS.sum()) * 100
turno2_zona13['Soma Acumuluda'] = turno2_zona13.QT_VOTOS.cumsum()
turno2_zona13['Portentagem Acumuluda'] = turno2_zona13['Porcentagem do Total'].cumsum()
display(turno2_zona13.head(13))
 
turno2_zona14 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 14].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona14['Porcentagem do Total'] = turno2_zona14.QT_VOTOS / (turno2_zona14.QT_VOTOS.sum()) * 100
turno2_zona14['Soma Acumuluda'] = turno2_zona14.QT_VOTOS.cumsum()
turno2_zona14['Portentagem Acumuluda'] = turno2_zona14['Porcentagem do Total'].cumsum()
display(turno2_zona14.head(13))
 
turno2_zona15 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 15].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona15['Porcentagem do Total'] = turno2_zona15.QT_VOTOS / (turno2_zona15.QT_VOTOS.sum()) * 100
turno2_zona15['Soma Acumuluda'] = turno2_zona15.QT_VOTOS.cumsum()
turno2_zona15['Portentagem Acumuluda'] = turno2_zona15['Porcentagem do Total'].cumsum()
display(turno2_zona15.head(13))
 
turno2_zona16 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 16].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona16['Porcentagem do Total'] = turno2_zona16.QT_VOTOS / (turno2_zona16.QT_VOTOS.sum()) * 100
turno2_zona16['Soma Acumuluda'] = turno2_zona16.QT_VOTOS.cumsum()
turno2_zona16['Portentagem Acumuluda'] = turno2_zona16['Porcentagem do Total'].cumsum()
display(turno2_zona16.head(13))
 
turno2_zona17 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 17].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona17['Porcentagem do Total'] = turno2_zona17.QT_VOTOS / (turno2_zona17.QT_VOTOS.sum()) * 100
turno2_zona17['Soma Acumuluda'] = turno2_zona17.QT_VOTOS.cumsum()
turno2_zona17['Portentagem Acumuluda'] = turno2_zona17['Porcentagem do Total'].cumsum()
display(turno2_zona17.head(13))
 
turno2_zona18 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 18].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona18['Porcentagem do Total'] = turno2_zona18.QT_VOTOS / (turno2_zona18.QT_VOTOS.sum()) * 100
turno2_zona18['Soma Acumuluda'] = turno2_zona18.QT_VOTOS.cumsum()
turno2_zona18['Portentagem Acumuluda'] = turno2_zona18['Porcentagem do Total'].cumsum()
display(turno2_zona18.head(13))
 
turno2_zona19 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 19].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona19['Porcentagem do Total'] = turno2_zona19.QT_VOTOS / (turno2_zona19.QT_VOTOS.sum()) * 100
turno2_zona19['Soma Acumuluda'] = turno2_zona19.QT_VOTOS.cumsum()
turno2_zona19['Portentagem Acumuluda'] = turno2_zona19['Porcentagem do Total'].cumsum()
display(turno2_zona19.head(13))
 
turno2_zona20 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 20].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona20['Porcentagem do Total'] = turno2_zona20.QT_VOTOS / (turno2_zona20.QT_VOTOS.sum()) * 100
turno2_zona20['Soma Acumuluda'] = turno2_zona20.QT_VOTOS.cumsum()
turno2_zona20['Portentagem Acumuluda'] = turno2_zona20['Porcentagem do Total'].cumsum()
display(turno2_zona20.head(13))
 
turno2_zona21 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 21].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona21['Porcentagem do Total'] = turno2_zona21.QT_VOTOS / (turno2_zona21.QT_VOTOS.sum()) * 100
turno2_zona21['Soma Acumuluda'] = turno2_zona21.QT_VOTOS.cumsum()
turno2_zona21['Portentagem Acumuluda'] = turno2_zona21['Porcentagem do Total'].cumsum()
display(turno2_zona21.head(13))
# Out:
#                   NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  Soma Acumuluda  \
# 0     JAIR MESSIAS BOLSONARO     32150             50.851747           32150
# 1  LUIZ INÁCIO LULA DA SILVA     28563             45.178179           60713
# 2                  VOTO NULO      1453              2.298214           62166
# 3                VOTO BRANCO      1057              1.671860           63223
#
#    Portentagem Acumuluda
# 0              50.851747
# 1              96.029926
# 2              98.328140
# 3             100.000000
#                   NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  Soma Acumuluda  \
# 0     JAIR MESSIAS BOLSONARO     49933             53.915757           49933
# 1  LUIZ INÁCIO LULA DA SILVA     39511             42.662477           89444
# 2                  VOTO NULO      1708              1.844234           91152
# 3                VOTO BRANCO      1461              1.577532           92613
#
#    Portentagem Acumuluda
# 0              53.915757
# ...

# %%
print('Ceilandia Norte') # ceilandia norte 
turno1_zona16

print('Samambaia')
turno1_zona13 # ceilandia 

truno2_estatistica = turno2[['NM_VOTAVEL', 'QT_VOTOS']].groupby('NM_VOTAVEL').sum().reset_index()

truno2_estatistica['Porcentagem Acumulada'] = truno2_estatistica.QT_VOTOS / truno2_estatistica.QT_VOTOS.sum() * 100 
truno2_estatistica['Votos Acumulado'] = truno2_estatistica.QT_VOTOS.cumsum()
truno2_estatistica

# ANALISE DE CADA ZONA ELEITORAL NO SEGUNDO TURNO

turno2_zona1 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 1].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona1['Porcentagem do Total'] = turno2_zona1.QT_VOTOS / (turno2_zona1.QT_VOTOS.sum()) * 100
turno2_zona1['Soma Acumuluda'] = turno2_zona1.QT_VOTOS.cumsum()
turno2_zona1['Portentagem Acumuluda'] = turno2_zona1['Porcentagem do Total'].cumsum()
display(turno2_zona1.head(13))
 
turno2_zona2 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 2].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona2['Porcentagem do Total'] = turno2_zona2.QT_VOTOS / (turno2_zona2.QT_VOTOS.sum()) * 100
turno2_zona2['Soma Acumuluda'] = turno2_zona2.QT_VOTOS.cumsum()
turno2_zona2['Portentagem Acumuluda'] = turno2_zona2['Porcentagem do Total'].cumsum()
display(turno2_zona2.head(13)
        )
turno2_zona3 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 3].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona3['Porcentagem do Total'] = turno2_zona3.QT_VOTOS / (turno2_zona3.QT_VOTOS.sum()) * 100
turno2_zona3['Soma Acumuluda'] = turno2_zona3.QT_VOTOS.cumsum()
turno2_zona3['Portentagem Acumuluda'] = turno2_zona3['Porcentagem do Total'].cumsum()
display(turno2_zona3.head(13))
 
turno2_zona4 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 4].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona4['Porcentagem do Total'] = turno2_zona4.QT_VOTOS / (turno2_zona4.QT_VOTOS.sum()) * 100
turno2_zona4['Soma Acumuluda'] = turno2_zona4.QT_VOTOS.cumsum()
turno2_zona4['Portentagem Acumuluda'] = turno2_zona4['Porcentagem do Total'].cumsum()
display(turno2_zona4.head(13))
 
turno2_zona5 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 5].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona5['Porcentagem do Total'] = turno2_zona5.QT_VOTOS / (turno2_zona5.QT_VOTOS.sum()) * 100
turno2_zona5['Soma Acumuluda'] = turno2_zona5.QT_VOTOS.cumsum()
turno2_zona5['Portentagem Acumuluda'] = turno2_zona5['Porcentagem do Total'].cumsum()
display(turno2_zona5.head(13))
 
turno2_zona6 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 6].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona6['Porcentagem do Total'] = turno2_zona6.QT_VOTOS / (turno2_zona6.QT_VOTOS.sum()) * 100
turno2_zona6['Soma Acumuluda'] = turno2_zona6.QT_VOTOS.cumsum()
turno2_zona6['Portentagem Acumuluda'] = turno2_zona6['Porcentagem do Total'].cumsum()
display(turno2_zona6.head(13))
 
turno2_zona8 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 8].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona8['Porcentagem do Total'] = turno2_zona8.QT_VOTOS / (turno2_zona8.QT_VOTOS.sum()) * 100
turno2_zona8['Soma Acumuluda'] = turno2_zona8.QT_VOTOS.cumsum()
turno2_zona8['Portentagem Acumuluda'] = turno2_zona8['Porcentagem do Total'].cumsum()
display(turno2_zona8.head(13))
 
turno2_zona9 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 9].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona9['Porcentagem do Total'] = turno2_zona9.QT_VOTOS / (turno2_zona9.QT_VOTOS.sum()) * 100
turno2_zona9['Soma Acumuluda'] = turno2_zona9.QT_VOTOS.cumsum()
turno2_zona9['Portentagem Acumuluda'] = turno2_zona9['Porcentagem do Total'].cumsum()
display(turno2_zona9.head(13))
 
turno2_zona10 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 10].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona10['Porcentagem do Total'] = turno2_zona10.QT_VOTOS / (turno2_zona10.QT_VOTOS.sum()) * 100
turno2_zona10['Soma Acumuluda'] = turno2_zona10.QT_VOTOS.cumsum()
turno2_zona10['Portentagem Acumuluda'] = turno2_zona10['Porcentagem do Total'].cumsum()
display(turno2_zona10.head(13))
 
turno2_zona11 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 11].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona11['Porcentagem do Total'] = turno2_zona11.QT_VOTOS / (turno2_zona11.QT_VOTOS.sum()) * 100
turno2_zona11['Soma Acumuluda'] = turno2_zona11.QT_VOTOS.cumsum()
turno2_zona11['Portentagem Acumuluda'] = turno2_zona11['Porcentagem do Total'].cumsum()
display(turno2_zona11.head(13))
 
# turno2_zona12 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 1].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
# turno2_zona12['Porcentagem do Total'] = turno2_zona12.QT_VOTOS / (turno2_zona12.QT_VOTOS.sum()) * 100
# turno2_zona12['Soma Acumuluda'] = turno2_zona12.QT_VOTOS.cumsum()
# turno2_zona12['Portentagem Acumuluda'] = turno2_zona12['Porcentagem do Total'].cumsum()
# display(turno2_zona12.head(13))
 
turno2_zona13 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 13].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona13['Porcentagem do Total'] = turno2_zona13.QT_VOTOS / (turno2_zona13.QT_VOTOS.sum()) * 100
turno2_zona13['Soma Acumuluda'] = turno2_zona13.QT_VOTOS.cumsum()
turno2_zona13['Portentagem Acumuluda'] = turno2_zona13['Porcentagem do Total'].cumsum()
display(turno2_zona13.head(13))
 
turno2_zona14 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 14].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona14['Porcentagem do Total'] = turno2_zona14.QT_VOTOS / (turno2_zona14.QT_VOTOS.sum()) * 100
turno2_zona14['Soma Acumuluda'] = turno2_zona14.QT_VOTOS.cumsum()
turno2_zona14['Portentagem Acumuluda'] = turno2_zona14['Porcentagem do Total'].cumsum()
display(turno2_zona14.head(13))
 
turno2_zona15 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 15].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona15['Porcentagem do Total'] = turno2_zona15.QT_VOTOS / (turno2_zona15.QT_VOTOS.sum()) * 100
turno2_zona15['Soma Acumuluda'] = turno2_zona15.QT_VOTOS.cumsum()
turno2_zona15['Portentagem Acumuluda'] = turno2_zona15['Porcentagem do Total'].cumsum()
display(turno2_zona15.head(13))
 
turno2_zona16 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 16].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona16['Porcentagem do Total'] = turno2_zona16.QT_VOTOS / (turno2_zona16.QT_VOTOS.sum()) * 100
turno2_zona16['Soma Acumuluda'] = turno2_zona16.QT_VOTOS.cumsum()
turno2_zona16['Portentagem Acumuluda'] = turno2_zona16['Porcentagem do Total'].cumsum()
display(turno2_zona16.head(13))
 
turno2_zona17 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 17].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona17['Porcentagem do Total'] = turno2_zona17.QT_VOTOS / (turno2_zona17.QT_VOTOS.sum()) * 100
turno2_zona17['Soma Acumuluda'] = turno2_zona17.QT_VOTOS.cumsum()
turno2_zona17['Portentagem Acumuluda'] = turno2_zona17['Porcentagem do Total'].cumsum()
display(turno2_zona17.head(13))
 
turno2_zona18 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 18].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona18['Porcentagem do Total'] = turno2_zona18.QT_VOTOS / (turno2_zona18.QT_VOTOS.sum()) * 100
turno2_zona18['Soma Acumuluda'] = turno2_zona18.QT_VOTOS.cumsum()
turno2_zona18['Portentagem Acumuluda'] = turno2_zona18['Porcentagem do Total'].cumsum()
display(turno2_zona18.head(13))
 
turno2_zona19 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 19].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona19['Porcentagem do Total'] = turno2_zona19.QT_VOTOS / (turno2_zona19.QT_VOTOS.sum()) * 100
turno2_zona19['Soma Acumuluda'] = turno2_zona19.QT_VOTOS.cumsum()
turno2_zona19['Portentagem Acumuluda'] = turno2_zona19['Porcentagem do Total'].cumsum()
display(turno2_zona19.head(13))
 
turno2_zona20 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 20].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona20['Porcentagem do Total'] = turno2_zona20.QT_VOTOS / (turno2_zona20.QT_VOTOS.sum()) * 100
turno2_zona20['Soma Acumuluda'] = turno2_zona20.QT_VOTOS.cumsum()
turno2_zona20['Portentagem Acumuluda'] = turno2_zona20['Porcentagem do Total'].cumsum()
display(turno2_zona20.head(13))
 
turno2_zona21 = turno2[['NM_VOTAVEL', 'QT_VOTOS']].loc[turno2.NR_ZONA == 21].groupby('NM_VOTAVEL').sum().sort_values( 'QT_VOTOS', ascending=False).reset_index()
 
turno2_zona21['Porcentagem do Total'] = turno2_zona21.QT_VOTOS / (turno2_zona21.QT_VOTOS.sum()) * 100
turno2_zona21['Soma Acumuluda'] = turno2_zona21.QT_VOTOS.cumsum()
turno2_zona21['Portentagem Acumuluda'] = turno2_zona21['Porcentagem do Total'].cumsum()
display(turno2_zona21.head(13))
# Out:
# Ceilandia Norte
# Samambaia
#                   NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  Soma Acumuluda  \
# 0     JAIR MESSIAS BOLSONARO     32150             50.851747           32150
# 1  LUIZ INÁCIO LULA DA SILVA     28563             45.178179           60713
# 2                  VOTO NULO      1453              2.298214           62166
# 3                VOTO BRANCO      1057              1.671860           63223
#
#    Portentagem Acumuluda
# 0              50.851747
# 1              96.029926
# 2              98.328140
# 3             100.000000
#                   NM_VOTAVEL  QT_VOTOS  Porcentagem do Total  Soma Acumuluda  \
# 0     JAIR MESSIAS BOLSONARO     49933             53.915757           49933
# 1  LUIZ INÁCIO LULA DA SILVA     39511             42.662477           89444
# 2                  VOTO NULO      1708              1.844234           91152
# 3                VOTO BRANCO      1461              1.577532           92613
#
#    Portentagem Acumuluda
# ...
